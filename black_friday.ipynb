# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv("C:/Users/0rame/Desktop/ML_tutorials/EDA/Datas/train.csv")

# %%
train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
train.shape
# Out:
# (550068, 12)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
train.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
train.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
train.duplicated().sum()
# Out:
# 0

# %%
train.select_dtypes('object').columns.to_list()
# Out:
# ['Product_ID', 'Gender', 'Age', 'City_Category', 'Stay_In_Current_City_Years']

# %%
train.select_dtypes('int64').columns.to_list()
# Out:
# ['User_ID', 'Occupation', 'Marital_Status', 'Product_Category_1', 'Purchase']

# %%
null_col = [i for i in train.columns if train[i].isnull().sum() > 0]

# %%
null_col
# Out:
# ['Product_Category_2', 'Product_Category_3']

# %%
import seaborn as sns

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
test = pd.read_csv("C:/Users/0rame/Desktop/ML_tutorials/EDA/Datas/test.csv")

# %%
test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
df = pd.concat([train, test], ignore_index=True)

# %%
df.shape
# Out:
# (783667, 12)

# %%
df.shape[0] == train.shape[0] + test.shape[0]
# Out:
# True

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
sns.scatterplot(x = df['Gender'],y = df['Purchase'],hue=df['Purchase'])
# Out:
# <Axes: xlabel='Gender', ylabel='Purchase'>
# Error in callback <function _draw_all_if_interactive at 0x000001ACCC164540> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\anaconda3\envs\venv2\Lib\site-packages\matplotlib\pyplot.py:120, in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#
# File ~\anaconda3\envs\venv2\Lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~\anaconda3\envs\venv2\Lib\site-packages\matplotlib\backend_bases.py:2082, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2080 if not self._is_idle_drawing:
# ...

# %%
sns.scatterplot(x = df['Occupation'],y = df['Purchase'],hue=df['Purchase'])
# Out:
# <Axes: xlabel='Occupation', ylabel='Purchase'>
# C:\Users\0rame\AppData\Roaming\Python\Python311\site-packages\IPython\core\events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# C:\Users\0rame\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.drop('User_ID',axis=1,inplace=True)

# %%
df.head()
# Out:
#   Product_ID Gender   Age  Occupation City_Category  \
# 0  P00069042      F  0-17          10             A
# 1  P00248942      F  0-17          10             A
# 2  P00087842      F  0-17          10             A
# 3  P00085442      F  0-17          10             A
# 4  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
col = df.select_dtypes(include='object').columns.tolist()

# %%
df2 = df.copy()

# %%
pd.get_dummies(df2[col])
# Out:
#         Product_ID_P00000142  Product_ID_P00000242  Product_ID_P00000342  \
# 0                      False                 False                 False
# 1                      False                 False                 False
# 2                      False                 False                 False
# 3                      False                 False                 False
# 4                      False                 False                 False
# ...                      ...                   ...                   ...
# 783662                 False                 False                 False
# 783663                 False                 False                 False
# 783664                 False                 False                 False
# 783665                 False                 False                 False
# 783666                 False                 False                 False
#
#         Product_ID_P00000442  Product_ID_P00000542  Product_ID_P00000642  \
# ...

# %%
df['Gender'] = df['Gender'].map({'F':0,'M':1})

# %%
df.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042       0  0-17          10             A
# 1  P00248942       0  0-17          10             A
# 2  P00087842       0  0-17          10             A
# 3  P00085442       0  0-17          10             A
# 4  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
df2['Gender'] = pd.get_dummies(df['Gender'],drop_first=True)

# %%
df2.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042   False  0-17          10             A
# 1  P00248942   False  0-17          10             A
# 2  P00087842   False  0-17          10             A
# 3  P00085442   False  0-17          10             A
# 4  P00285442    True   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# ...

# %%
plt.figure(figsize=(10,6))
sns.countplot(data = df,x = 'Gender')
plt.title("gender count")
plt.xlabel("gender")
plt.ylabel("count")
plt.show()

# %%
df['Gender'].value_counts()
# Out:
# Gender
# 1    590031
# 0    193636
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(data = df,x = 'Age')
plt.title("Age count")
plt.xlabel("Age")
plt.ylabel("count")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data = df,x = 'City_Category')
plt.title("City_Category count")
plt.xlabel("City_Category")
plt.ylabel("count")
plt.show()

# %% [markdown]
# #### highest purchasing age group

# %%
grp = df.groupby(['Age','Purchase']).size().reset_index().rename(columns={0:'count'}).sort_values('count',ascending=False)[:1]

# %%
grp
# Out:
#          Age  Purchase  count
# 26788  26-35    7167.0     87

# %%
df
# Out:
#        Product_ID Gender    Age  Occupation City_Category  \
# 0       P00069042      F   0-17          10             A
# 1       P00248942      F   0-17          10             A
# 2       P00087842      F   0-17          10             A
# 3       P00085442      F   0-17          10             A
# 4       P00285442      M    55+          16             C
# ...           ...    ...    ...         ...           ...
# 783662  P00118942      F  26-35          15             B
# 783663  P00254642      F  26-35          15             B
# 783664  P00031842      F  26-35          15             B
# 783665  P00124742      F  46-50           1             C
# 783666  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
sns.scatterplot(x=df['Marital_Status'],y=df['Purchase'],hue=df['Purchase'])
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Purchase'>

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
plt.figure(figsize=(10,6))
sns.countplot(data = df,x = 'Marital_Status')
plt.title("Marital_Status count")
plt.xlabel("Marital_Status")
plt.ylabel("count")
plt.show()

# %%
col
# Out:
# ['Product_ID', 'Gender', 'Age', 'City_Category', 'Stay_In_Current_City_Years']

# %% [markdown]
# ### here Age is also categorical data,need todo label encoding

# %%
ages = pd.get_dummies(df2['Age'],drop_first=True)
ages
# Out:
#         18-25  26-35  36-45  46-50  51-55    55+
# 0       False  False  False  False  False  False
# 1       False  False  False  False  False  False
# 2       False  False  False  False  False  False
# 3       False  False  False  False  False  False
# 4       False  False  False  False  False   True
# ...       ...    ...    ...    ...    ...    ...
# 783662  False   True  False  False  False  False
# 783663  False   True  False  False  False  False
# 783664  False   True  False  False  False  False
# 783665  False  False  False   True  False  False
# 783666  False  False  False   True  False  False
#
# [783667 rows x 6 columns]

# %%
df2 = df.copy()

# %%
df2
# Out:
#        Product_ID  Gender    Age  Occupation City_Category  \
# 0       P00069042       0   0-17          10             A
# 1       P00248942       0   0-17          10             A
# 2       P00087842       0   0-17          10             A
# 3       P00085442       0   0-17          10             A
# 4       P00285442       1    55+          16             C
# ...           ...     ...    ...         ...           ...
# 783662  P00118942       0  26-35          15             B
# 783663  P00254642       0  26-35          15             B
# 783664  P00031842       0  26-35          15             B
# 783665  P00124742       0  46-50           1             C
# 783666  P00316642       0  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df2 = pd.concat([df2,ages],axis=1)
df2
# Out:
#        Product_ID  Gender    Age  Occupation City_Category  \
# 0       P00069042       0   0-17          10             A
# 1       P00248942       0   0-17          10             A
# 2       P00087842       0   0-17          10             A
# 3       P00085442       0   0-17          10             A
# 4       P00285442       1    55+          16             C
# ...           ...     ...    ...         ...           ...
# 783662  P00118942       0  26-35          15             B
# 783663  P00254642       0  26-35          15             B
# 783664  P00031842       0  26-35          15             B
# 783665  P00124742       0  46-50           1             C
# 783666  P00316642       0  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
df2.drop('Age',inplace=True,axis=1)

# %%
df2
# Out:
#        Product_ID  Gender  Occupation City_Category  \
# 0       P00069042       0          10             A
# 1       P00248942       0          10             A
# 2       P00087842       0          10             A
# 3       P00085442       0          10             A
# 4       P00285442       1          16             C
# ...           ...     ...         ...           ...
# 783662  P00118942       0          15             B
# 783663  P00254642       0          15             B
# 783664  P00031842       0          15             B
# 783665  P00124742       0           1             C
# 783666  P00316642       0           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# ...

# %%
df['Age'] = df['Age'].map({'0-17':1,'18-25':2,'26-35':3,'36-45':4,'46-50':5,'51-55':6,'55+':7})

# %%
df
# Out:
#        Product_ID  Gender  Age  Occupation City_Category  \
# 0       P00069042       0    1          10             A
# 1       P00248942       0    1          10             A
# 2       P00087842       0    1          10             A
# 3       P00085442       0    1          10             A
# 4       P00285442       1    7          16             C
# ...           ...     ...  ...         ...           ...
# 783662  P00118942       0    3          15             B
# 783663  P00254642       0    3          15             B
# 783664  P00031842       0    3          15             B
# 783665  P00124742       0    5           1             C
# 783666  P00316642       0    5           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %% [markdown]
# ### by using label encoding dealing age column in df2

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
df2
# Out:
#        Product_ID  Gender  Occupation City_Category  \
# 0       P00069042       0          10             A
# 1       P00248942       0          10             A
# 2       P00087842       0          10             A
# 3       P00085442       0          10             A
# 4       P00285442       1          16             C
# ...           ...     ...         ...           ...
# 783662  P00118942       0          15             B
# 783663  P00254642       0          15             B
# 783664  P00031842       0          15             B
# 783665  P00124742       0           1             C
# 783666  P00316642       0           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# ...

# %%
for i in df.select_dtypes('object'):
    df[i] = encoder.fit_transform(df[i])

# %%
df.dtypes
# Out:
# Product_ID                      int32
# Gender                          int64
# Age                             int64
# Occupation                      int64
# City_Category                   int32
# Stay_In_Current_City_Years      int32
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# dtype: object

# %% [markdown]
# ### dealing with missing values

# %%
df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# dtype: int64

# %%
df['Product_Category_2'] = df['Product_Category_2'].fillna(df['Product_Category_2'].mode()[0])

# %%
df['Product_Category_3'] = df['Product_Category_3'].fillna(df['Product_Category_3'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2                 0
# Product_Category_3                 0
# Purchase                      233599
# dtype: int64

# %% [markdown]
# you can use str.replace function to remove charctrs from the column data ie
#
# df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].str.replace('+','')
#
# it will replace + from that column with space

# %% [markdown]
# to convert types of columns use astype() ie
#
# df["City_Category"] = df['City_Category'].astype("int")

# %% [markdown]
# ### Visualization

# %%
sns.barplot(x=df['Age'],y=df['Purchase'],hue=df['Gender'])
# Out:
# <Axes: xlabel='Age', ylabel='Purchase'>

# %% [markdown]
# ### purchasing of men is higher than women

# %%
cor = df.corr()

# %%
# Get upper triangle of correlation matrix
upper_triangle = cor.where(np.triu(np.ones(cor.shape), k=1).astype(bool))

# Find features with correlation greater than 98%
highly_correlated = upper_triangle.abs().stack().sort_values(ascending=False)
highly_correlated = highly_correlated[highly_correlated > 0.80]

# Print highly correlated feature pairs
print(highly_correlated)
# Out:
# Series([], dtype: float64)

# %%
from scipy.stats import norm
plt.figure(figsize=(10,6))
sns.distplot(df['Gender'])
plt.title("distribution of gender")
plt.xlabel("gender")
plt.show()
# Out:
# C:\Users\0rame\AppData\Local\Temp\ipykernel_14232\3165655339.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Gender'])

# %%
df.skew()
# Out:
# Product_ID                    0.150259
# Gender                       -1.172731
# Age                           0.808914
# Occupation                    0.399767
# City_Category                -0.071390
# Stay_In_Current_City_Years    0.318568
# Marital_Status                0.366914
# Product_Category_1            0.986594
# Product_Category_2            0.195204
# Product_Category_3           -2.688593
# Purchase                      0.600140
# dtype: float64

# %% [markdown]
# gender and product_category_3 are showing high -ve skewness

# %% [markdown]
# #### removing skewness

# %%
from scipy import sqrt
df['Gender'] = np.sqrt(df['Gender'])
df['Product_Category_3'] = np.sqrt(df['Product_Category_3'])

# %%
df.skew()
# Out:
# Product_ID                    0.150259
# Gender                       -1.172731
# Age                           0.808914
# Occupation                    0.399767
# City_Category                -0.071390
# Stay_In_Current_City_Years    0.318568
# Marital_Status                0.366914
# Product_Category_1            0.986594
# Product_Category_2            0.195204
# Product_Category_3           -2.907528
# Purchase                      0.600140
# dtype: float64

# %%
sns.boxplot(df['Gender'],orient='h')
plt.title("boxplot of gender")
plt.xlabel("gender")
plt.show()

# %%
df1 = df.copy()

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df1))
df1 =  df1[(z<3).all(axis=1)]

# %%
df['Purchase'].isnull().sum()
# Out:
# 233599

# %% [markdown]
# converting df into train and test,in which test contains target varibales which are null and train containinfg purchsse values

# %%
df_train = df[~df['Purchase'].isnull()]

# %%
df_test = df[df['Purchase'].isnull()]

# %%
df_train
# Out:
#         Product_ID  Gender  Age  Occupation  City_Category  \
# 0              684     0.0    1          10              0
# 1             2406     0.0    1          10              0
# 2              868     0.0    1          10              0
# 3              844     0.0    1          10              0
# 4             2769     1.0    7          16              2
# ...            ...     ...  ...         ...            ...
# 550063        3612     1.0    6          13              1
# 550064        3613     0.0    3           1              2
# 550065        3613     0.0    3          15              1
# 550066        3613     0.0    7           1              2
# 550067        3611     0.0    5           0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               0                   3
# 1                                2               0                   1
# ...

# %%
df_test
# Out:
#         Product_ID  Gender  Age  Occupation  City_Category  \
# 550068        1216     1.0    5           7              1
# 550069        1063     1.0    3          17              2
# 550070        2799     0.0    4           1              1
# 550071        1379     0.0    4           1              1
# 550072         535     0.0    3           1              2
# ...            ...     ...  ...         ...            ...
# 783662        1118     0.0    3          15              1
# 783663        2463     0.0    3          15              1
# 783664         315     0.0    3          15              1
# 783665        1175     0.0    5           1              2
# 783666        3074     0.0    5           0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550068                           2               1                   1
# 550069                           0               0                   3
# ...

# %% [markdown]
# here you can see there all null values for purchase column in df_test

# %% [markdown]
# #### Feature Scaling

# %%
x = df.iloc[:,:-1]

# %%
x
# Out:
#         Product_ID  Gender  Age  Occupation  City_Category  \
# 0              684     0.0    1          10              0
# 1             2406     0.0    1          10              0
# 2              868     0.0    1          10              0
# 3              844     0.0    1          10              0
# 4             2769     1.0    7          16              2
# ...            ...     ...  ...         ...            ...
# 783662        1118     0.0    3          15              1
# 783663        2463     0.0    3          15              1
# 783664         315     0.0    3          15              1
# 783665        1175     0.0    5           1              2
# 783666        3074     0.0    5           0              1
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               0                   3
# 1                                2               0                   1
# ...

# %%
y = df.iloc[:,-1]

# %%
x.shape
# Out:
# (783667, 10)

# %%
y.shape
# Out:
# (783667,)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
xtrain = scaler.fit_transform(xtrain)

# %%
xtest = scaler.transform(xtest)
