# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("C:/Users/0rame/Desktop/ML_tutorials/EDA/Datas/zomato.csv",delimiter=",",encoding='latin-1')

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
text_col = data.select_dtypes(include=['object']).columns.to_list()

# %%
text_col = data.select_dtypes(include=['object']).columns.to_list()

# %%
text_col
# Out:
# ['Restaurant Name',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Cuisines',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Rating color',
#  'Rating text']

# %%
num_col = data.select_dtypes(include=['int64']).columns.to_list()

# %%
num_col
# Out:
# ['Restaurant ID',
#  'Country Code',
#  'Average Cost for two',
#  'Price range',
#  'Votes']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
[i for i in data.columns if data[i].isnull().sum() > 0]
# Out:
# ['Cuisines']

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df_country = pd.read_excel("C:/Users/0rame/Desktop/ML_tutorials/EDA/Datas/Country-Code.xlsx")

# %%
df_country.columns
# Out:
# Index(['Country Code', 'Country'], dtype='object')

# %%
df = pd.concat([df_country,data],axis=1)

# %%
df.head()
# Out:
#    Country Code    Country  Restaurant ID         Restaurant Name  \
# 0           1.0      India        6317637        Le Petit Souffle
# 1          14.0  Australia        6304287        Izakaya Kikufuji
# 2          30.0     Brazil        6300002  Heat - Edsa Shangri-La
# 3          37.0     Canada        6318506                    Ooma
# 4          94.0  Indonesia        6314302             Sambo Kojin
#
#    Country Code              City  \
# 0           162       Makati City
# 1           162       Makati City
# 2           162  Mandaluyong City
# 3           162  Mandaluyong City
# 4           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
# ...

# %%
df_final = pd.merge(data,df_country,on='Country Code',how="inner")

# %%
df_final.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
# 1                    Japanese  ...                Yes                  No
#
# ...

# %%
countries = df_final['Country'].value_counts().index

# %%
countries_count = df_final['Country'].value_counts().values

# %% [markdown]
# ### top 3 counrtries with highest zomata transaction record

# %%
plt.pie(countries_count[:3],labels=countries[:3],autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x270cbf93f50>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.39%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.73%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.87%')])

# %% [markdown]
# ### pie plots are created by using value_counts() ---value and index

# %%
df_final.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
rating_count = df_final.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'rating count'})
#here reset_index() fn is used to converrt this groupby into a dataframe and then used rename function to rename last column which is named as 0 when size() fn is perfomred

# %%
rating_count.head()
# Out:
#    Aggregate rating Rating color Rating text  rating count
# 0               0.0        White   Not rated          2148
# 1               1.8          Red        Poor             1
# 2               1.9          Red        Poor             2
# 3               2.0          Red        Poor             7
# 4               2.1          Red        Poor            15

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (10,8)
sns.barplot(x='Aggregate rating',y="rating count",data=rating_count)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='rating count'>

# %%
matplotlib.rcParams['figure.figsize']
# Out:
# [10.0, 8.0]

# %%
#doing same barplot of rating count with using value_counts()

ratings = df_final['Aggregate rating'].value_counts().index

ratings

rating_counts = df_final['Aggregate rating'].value_counts().values

rating_counts

sns.barplot(x=ratings,y=rating_counts)
# Out:
# <Axes: xlabel='Aggregate rating'>

# %%
rating_count
# Out:
#     Aggregate rating Rating color Rating text  rating count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
sns.countplot(x="Rating color",data=rating_count)
# Out:
# <Axes: xlabel='Rating color', ylabel='count'>

# %%
#country count with 0 ratings
df_final[df_final['Aggregate rating'] == 0].groupby(['Country']).size().reset_index().rename(columns={0:'count'})
# Out:
#           Country  count
# 0          Brazil      5
# 1           India   2139
# 2  United Kingdom      1
# 3   United States      3

# %%
df_final.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
top_rest = df_final[['Restaurant Name','Votes']].sort_values('Votes',ascending=False)

# %%
top_rest
# Out:
#                 Restaurant Name  Votes
# 728                        Toit  10934
# 735                    Truffles   9667
# 3994           Hauz Khas Social   7931
# 2412                  Peter Cat   7574
# 739   AB's - Absolute Barbecues   6907
# ...                         ...    ...
# 1015                  Fritrolla      0
# 3958      Adda The Spice Affair      0
# 1007               Tandoori Hut      0
# 1006                Hungry Head      0
# 4524    Singh Chinese Fast Food      0
#
# [9551 rows x 2 columns]

# %%
# plt.pie(x=top_rest['Votes'][:3],labels=top_rest['Restaurant Name'][:3],autopct="%1.22f%%")

# %%
top_cities = df_final.groupby(['City']).size().reset_index().rename(columns={0:'count'})

# %%
df_final.select_dtypes(include=['object']).columns.to_list()
# Out:
# ['Restaurant Name',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Cuisines',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Rating color',
#  'Rating text',
#  'Country']

# %% [markdown]
# ### countries with thier currencies

# %%
countries_currency = df_final.groupby(['Country','Currency']).size().reset_index().rename(columns={0:'count'}).sort_values('count',ascending=False)

# %%
countries_currency
# Out:
#            Country                Currency  count
# 3            India      Indian Rupees(Rs.)   8652
# 14   United States               Dollar($)    434
# 13  United Kingdom              Pounds(£)     80
# 1           Brazil      Brazilian Real(R$)     60
# 9     South Africa                 Rand(R)     60
# 12             UAE      Emirati Diram(AED)     60
# 5      New Zealand           NewZealand($)     40
# 11          Turkey        Turkish Lira(TL)     34
# 0        Australia               Dollar($)     24
# 6      Phillipines        Botswana Pula(P)     22
# 4        Indonesia  Indonesian Rupiah(IDR)     21
# 7            Qatar         Qatari Rial(QR)     20
# 8        Singapore               Dollar($)     20
# 10       Sri Lanka   Sri Lankan Rupee(LKR)     20
# 2           Canada               Dollar($)      4

# %%
df_final.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# #### country with online delivery

# %%
country_with_delivery = df_final[df_final['Is delivering now'] == 'Yes']['Country'].value_counts().index.tolist()

# %%
country_with_delivery
# Out:
# ['India']

# %%
df_final[df_final['Is delivering now'] == 'Yes']['Country'].value_counts().index.tolist()
# Out:
# ['India']

# %% [markdown]
# ### top 10 cuisines

# %%
df_final[['Restaurant Name','Aggregate rating','Rating text']].sort_values('Aggregate rating',ascending=False)[:10]
# Out:
#                     Restaurant Name  Aggregate rating Rating text
# 1381                    Caterspoint               4.9   Excellent
# 589         AB's Absolute Barbecues               4.9   Excellent
# 352   McGuire's Irish Pub & Brewery               4.9   Excellent
# 405               Mama's Fish House               4.9   Excellent
# 406                   Marukame Udon               4.9   Excellent
# 9303                          Miann               4.9   Excellent
# 50                Garota de Ipanema               4.9   Excellent
# 9299                          Milse               4.9   Excellent
# 48               Braseiro da Gíçvea               4.9   Excellent
# 9296               Talaga Sampireun               4.9   Excellent
